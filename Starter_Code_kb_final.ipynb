# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df=application_df.drop(columns=['EIN', 'NAME'], axis=1)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
a=application_df['APPLICATION_TYPE'].value_counts()
a=pd.DataFrame(a)

# %%
a
# Out:
#      APPLICATION_TYPE
# T3              27037
# T4               1542
# T6               1216
# T5               1173
# T19              1065
# T8                737
# T7                725
# T10               528
# T9                156
# T13                66
# T12                27
# T2                 16
# T25                 3
# T14                 3
# T29                 2
# T15                 2
# T17                 1

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace=[]

# %%
for x in range(8, 17):
  application_types_to_replace.append(a.index[x])
  print(a.index[x])
# Out:
# T9
# T13
# T12
# T2
# T25
# T14
# T29
# T15
# T17

# %%
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
val=application_df['CLASSIFICATION'].value_counts()
print(val[val>1])
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace=[]
c=application_df['CLASSIFICATION'].value_counts()
c=pd.DataFrame(c)
c
# Out:
#        CLASSIFICATION
# C1000           17326
# C2000            6074
# C1200            4837
# C3000            1918
# C2100            1883
# ...               ...
# C4120               1
# C8210               1
# C2561               1
# C4500               1
# C2150               1
#
# [71 rows x 1 columns]

# %%
classifications_to_replace.append(c[c.CLASSIFICATION<1883].index)

# %%
print(classifications_to_replace)
# Out:
# [Index(['C7000', 'C1700', 'C4000', 'C5000', 'C1270', 'C2700', 'C2800', 'C7100',
#        'C1300', 'C1280', 'C1230', 'C1400', 'C7200', 'C2300', 'C1240', 'C8000',
#        'C7120', 'C1500', 'C1800', 'C6000', 'C1250', 'C8200', 'C1238', 'C1278',
#        'C1235', 'C1237', 'C7210', 'C2400', 'C1720', 'C4100', 'C1257', 'C1600',
#        'C1260', 'C2710', 'C0', 'C3200', 'C1234', 'C1246', 'C1267', 'C1256',
#        'C2190', 'C4200', 'C2600', 'C5200', 'C1370', 'C1248', 'C6100', 'C1820',
#        'C1900', 'C1236', 'C3700', 'C2570', 'C1580', 'C1245', 'C2500', 'C1570',
#        'C1283', 'C2380', 'C1732', 'C1728', 'C2170', 'C4120', 'C8210', 'C2561',
#        'C4500', 'C2150'],
#       dtype='object')]

# %%
# for x in c[c.CLASSIFICATION<1883]:
#     classifications_to_replace.append(c.index)
#     print(c.index)

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df=pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y=application_df['IS_SUCCESSFUL']
X=application_df.drop(columns='IS_SUCCESSFUL', axis=1)

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train.columns)
hidden_nodes_layer1 =  50
hidden_nodes_layer2 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
Dense1=tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="tanh")
nn.add(Dense1)

# Second hidden layer
Dense2=tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu")
nn.add(Dense2)

# Output layer
Dense3=tf.keras.layers.Dense(units=1, activation="sigmoid")
nn.add(Dense3)

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 50)                2200
#
#  dense_8 (Dense)             (None, 10)                510
#
#  dense_9 (Dense)             (None, 1)                 11
#
# ...
# Total params: 2,721
# Trainable params: 2,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5778 - accuracy: 0.7161
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5564 - accuracy: 0.7279
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5533 - accuracy: 0.7304
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7294
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5496 - accuracy: 0.7306
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5492 - accuracy: 0.7315
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5481 - accuracy: 0.7318
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5474 - accuracy: 0.7311
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5471 - accuracy: 0.7322
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5541 - accuracy: 0.7290 - 538ms/epoch - 2ms/step
# Loss: 0.5540549159049988, Accuracy: 0.7289795875549316

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train.columns)
hidden_nodes_layer1 =  25
hidden_nodes_layer2 = 2

nn2 = tf.keras.models.Sequential()

# First hidden layer
Dense1=tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
nn2.add(Dense1)

# Second hidden layer
Dense2=tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu")
nn2.add(Dense2)

# Output layer
Dense3=tf.keras.layers.Dense(units=1, activation="sigmoid")
nn2.add(Dense3)

# Check the structure of the model
nn2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 25)                1100
#
#  dense_1 (Dense)             (None, 2)                 52
#
#  dense_2 (Dense)             (None, 1)                 3
#
# ...
# Total params: 1,155
# Trainable params: 1,155
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn2.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.6201 - accuracy: 0.6554
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5610 - accuracy: 0.7227
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5557 - accuracy: 0.7282
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5540 - accuracy: 0.7284
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5526 - accuracy: 0.7309
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5519 - accuracy: 0.7306
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5514 - accuracy: 0.7305
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5505 - accuracy: 0.7303
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5501 - accuracy: 0.7321
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5548 - accuracy: 0.7277 - 463ms/epoch - 2ms/step
# Loss: 0.554794430732727, Accuracy: 0.7276967763900757

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train.columns)
hidden_nodes_layer1 =  15
hidden_nodes_layer2 = 3

nn3 = tf.keras.models.Sequential()

# First hidden layer
Dense1=tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
nn3.add(Dense1)

# Second hidden layer
Dense2=tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu")
nn3.add(Dense2)

# Output layer
Dense3=tf.keras.layers.Dense(units=1, activation="sigmoid")
nn3.add(Dense3)

# Check the structure of the model
nn3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 15)                660
#
#  dense_4 (Dense)             (None, 3)                 48
#
#  dense_5 (Dense)             (None, 1)                 4
#
# ...
# Total params: 712
# Trainable params: 712
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn3.fit(X_train_scaled,y_train,epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 2s 1ms/step - loss: 0.6335 - accuracy: 0.6765
# Epoch 2/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5832 - accuracy: 0.7265
# Epoch 3/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5735 - accuracy: 0.7272
# Epoch 4/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5690 - accuracy: 0.7288
# Epoch 5/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5666 - accuracy: 0.7284
# Epoch 6/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5643 - accuracy: 0.7304
# Epoch 7/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5619 - accuracy: 0.7300
# Epoch 8/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5606 - accuracy: 0.7301
# Epoch 9/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5598 - accuracy: 0.7306
# Epoch 10/200
# ...

# %%
model_loss, model_accuracy = nn3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5563 - accuracy: 0.7280 - 460ms/epoch - 2ms/step
# Loss: 0.5563033223152161, Accuracy: 0.7280466556549072

# %%
# from sklearn.ensemble import RandomForestClassifier
# rf_model = RandomForestClassifier(n_estimators=500, random_state=1)
# rf_model = rf_model.fit(X_train_scaled, y_train)
# predictions = rf_model.predict(X_test_scaled)

# %%
# from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# cm = confusion_matrix(y_test, predictions)
# cm_df = pd.DataFrame(
#     cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
# )

# # Calculating the accuracy score
# acc_score = accuracy_score(y_test, predictions)
# print("Confusion Matrix")
# display(cm_df)
# print(f"Accuracy Score : {acc_score}")
# print("Classification Report")
# print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0         2720         1317
# Actual 1         1168         3370
# Accuracy Score : 0.710204081632653
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.70      0.67      0.69      4037
#            1       0.72      0.74      0.73      4538
#
#     accuracy                           0.71      8575
#    macro avg       0.71      0.71      0.71      8575
# weighted avg       0.71      0.71      0.71      8575

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")
